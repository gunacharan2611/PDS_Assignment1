# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Frailty.csv')
print(df.to_string())
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Height Weight  Age Grip Strength Frailty
# 0             0             0           0  65.8    112   30            30       N
# 1             1             1           1  71.5    136   19            31       N
# 2             2             2           2  69.4    153   45            29       N
# 3             3             3           3  68.2    142   22            28       Y
# 4             4             4           4  67.8    144   29            24       Y
# 5             5             5           5  68.7    123   50            26       N
# 6             6             6           6  69.8    141   51            22       Y
# 7             7             7           7  70.1    136   23            20       Y
# 8             8             8           8  67.9    112   17            19       N
# 9             9             9           9  66.8    120   39            31       N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.2   10 non-null     int64
#  1   Unnamed: 0.1   10 non-null     int64
#  2   Unnamed: 0     10 non-null     int64
#  3   Height         10 non-null     object
#  4   Weight         10 non-null     object
#  5   Age            10 non-null     object
#  6   Grip Strength  10 non-null     object
#  7   Frailty        10 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 768.0+ bytes

# %%
axis = df.plot.scatter(x='Weight',y='Grip Strength')
fig = axis.get_figure()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Frailty', data=df)
plt.title('Frailty Distribution')
plt.show()
